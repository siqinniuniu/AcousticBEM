# %%
from CompoundExponential import *
# %matplotlib inline

# %%
horn = CompoundExponentialHorn("CE Horn", 0.0254 / 2.0, 1200.0, 30, 0.10)
horn.plotConeSection()

# %%
# %%time
aFrequency = np.array([1000, 2000, 4000, 8000, 16000], dtype=np.float32)
horn.makePolarPlot(aFrequency)
# Out:
# CPU times: user 671 ms, sys: 74 ms, total: 745 ms
# Wall time: 25.6 s

# %%
# %%time
#horn.frequencyRange = (1600, 16000)
horn.makePolarMap()
# Out:
# CPU times: user 707 ms, sys: 59.3 ms, total: 766 ms
# Wall time: 29min 2s

# %%
# %%time
horn.makeImpedancePlot()
# Out:
# CPU times: user 610 ms, sys: 46.4 ms, total: 656 ms
# Wall time: 19min 29s
