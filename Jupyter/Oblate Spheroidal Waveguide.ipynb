# %%
from OblateSpheroidalWaveguide import *
# %matplotlib inline

# %%
horn = OblateSpheroidalWaveguide("OS Waveguide", 0.0254 / 2.0, 45.0, 0.05, 3 * 0.0254, 0.005)
print("Cutoff frequency = {}".format(horn.cutoff_frequency()))
horn.plot_cone_section()
# Out:
# Cutoff frequency = 1219.32603448049

# %%
# %%time
frequencies = np.array([1000, 2000, 4000, 8000, 16000], dtype=np.float32)
horn.make_polar_plot(frequencies)
# Out:
# CPU times: user 678 ms, sys: 37.3 ms, total: 715 ms
# Wall time: 26.2 s

# %%
# %%time
#horn.frequencyRange = (1600, 16000)
horn.make_polar_map()
# Out:
# CPU times: user 1.48 s, sys: 69.7 ms, total: 1.55 s
# Wall time: 26min 2s

# %%
# %%time
horn.make_impedance_plot()
# Out:
# CPU times: user 1.34 s, sys: 34.3 ms, total: 1.37 s
# Wall time: 6min 28s
