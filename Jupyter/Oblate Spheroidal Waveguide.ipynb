# %%
from OblateSpheroidalWaveguide import *
# %matplotlib inline

# %%
horn = OblateSpheroidalWaveguide("OS Waveguide", 0.0254 / 2.0, 45.0, 0.05, 3 * 0.0254, 0.005)
print("Cutoff frequency = {}".format(horn.cutoffFrequency()))
horn.plotConeSection()
# Out:
# Cutoff frequency = 1219.32603448049

# %%
# %%time
aFrequency = np.array([1000, 2000, 4000, 8000, 16000], dtype=np.float32)
horn.makePolarPlot(aFrequency)
# Out:
# CPU times: user 665 ms, sys: 120 ms, total: 785 ms
# Wall time: 27.6 s

# %%
# %%time
#horn.frequencyRange = (1600, 16000)
horn.makePolarMap()
# Out:
# CPU times: user 741 ms, sys: 53.3 ms, total: 795 ms
# Wall time: 45min 38s

# %%
# %%time
horn.makeImpedancePlot()
# Out:
# CPU times: user 599 ms, sys: 53.8 ms, total: 653 ms
# Wall time: 17min 12s
