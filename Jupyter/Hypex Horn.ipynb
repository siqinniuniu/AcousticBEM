# %%
from HypexHorn import *
# %matplotlib inline

# %%
horn = HypexHorn("Exponential Horn", 0.012, 500.0, 0.3)
horn.plotConeSection()

# %%
# %%time
aFrequency = np.array([1000, 2000, 4000, 8000, 16000], dtype=np.float32)
horn.makePolarPlot(aFrequency)
# Out:
# CPU times: user 701 ms, sys: 185 ms, total: 886 ms
# Wall time: 20.6 s

# %%
# %%time
#horn.frequencyRange = (1600, 16000)
horn.makePolarMap()
# Out:
# CPU times: user 727 ms, sys: 102 ms, total: 829 ms
# Wall time: 54min 43s

# %%
# %%time
horn.makeImpedancePlot()
# Out:
# CPU times: user 605 ms, sys: 75.3 ms, total: 680 ms
# Wall time: 23min 5s
