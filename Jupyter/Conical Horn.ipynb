# %%
from ConicalHorn import *
# %matplotlib inline

# %%
# 10 Inch Waveguide 25cm -> 12cm cone radius
# 1 Inch driver -> 24mm radius
# ~30 degree angle (to match typical woofer) -> ~6cm depth/length
s = ConicalHorn('10 Inch Waveguide', 0.012, 0.12, 0.12, 0.005)
s.plot_cone_section()

# %%
# %%time
frequencies = np.array([1000, 2000, 4000, 8000, 16000], dtype=np.float32)
s.make_polar_plot(frequencies)
# Out:
# CPU times: user 627 ms, sys: 21.8 ms, total: 649 ms
# Wall time: 12.5 s

# %%
# %%time
#s.frequencyRange = (1600, 16000)
s.make_polar_map()
# Out:
# CPU times: user 1.55 s, sys: 81.6 ms, total: 1.63 s
# Wall time: 19min 18s

# %%
# %%time
s.make_impedance_plot()
# Out:
# CPU times: user 1.41 s, sys: 57.4 ms, total: 1.47 s
# Wall time: 14min 32s
