# %%
from ConicalHorn import *
# %matplotlib inline

# %%
# 10 Inch Waveguide 25cm -> 12cm cone radius
# 1 Inch driver -> 26mm radius
# ~30 degree angle (to match typical woofer) -> ~6cm depth/length
s = ConicalHorn('10 Inch Waveguide', 0.012, 0.12, 0.12, 0.005)
s.plotConeSection()

# %%
# %%time
aFrequency = np.array([1000, 2000, 4000, 8000, 16000], dtype=np.float32)
s.makePolarPlot(aFrequency)
# Out:
# CPU times: user 714 ms, sys: 375 ms, total: 1.09 s
# Wall time: 11.9 s

# %%
# %%time
#s.frequencyRange = (1600, 16000)
s.makePolarMap()
# Out:
# CPU times: user 699 ms, sys: 102 ms, total: 800 ms
# Wall time: 28min 36s

# %%
# %%time
s.makeImpedancePlot()
# Out:
# CPU times: user 556 ms, sys: 126 ms, total: 682 ms
# Wall time: 40min 33s
