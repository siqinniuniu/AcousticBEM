# %%
from TractrixHorn import *
# %matplotlib inline

# %%
horn = TractrixHorn("Tractrix Horn", 0.012, 500.0)
horn.plot_cone_section()
# Out:
# samples_y[-1] = 0.012

# %%
# %%time
frequencies = np.array([1000, 2000, 4000, 8000, 16000], dtype=np.float32)
horn.make_polar_plot(frequencies)
# Out:
# CPU times: user 682 ms, sys: 46.1 ms, total: 728 ms
# Wall time: 7.43 s

# %%
# %%time
#horn.frequencyRange = (1600, 16000)
horn.make_polar_map()
# Out:
# CPU times: user 1.51 s, sys: 56.4 ms, total: 1.56 s
# Wall time: 12min 13s

# %%
# %%time
horn.make_impedance_plot()
# Out:
# CPU times: user 1.3 s, sys: 95.7 ms, total: 1.39 s
# Wall time: 9min 2s
