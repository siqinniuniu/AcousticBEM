# %%
from TractrixHorn import *
# %matplotlib inline

# %%
horn = TractrixHorn("Tractrix Horn", 0.012, 500.0)
horn.plotConeSection()
# Out:
# aSamplesY[-1] = 0.012

# %%
# %%time
aFrequency = np.array([1000, 2000, 4000, 8000, 16000], dtype=np.float32)
horn.makePolarPlot(aFrequency)
# Out:
# CPU times: user 657 ms, sys: 440 ms, total: 1.1 s
# Wall time: 4.98 s

# %%
# %%time
#horn.frequencyRange = (1600, 16000)
horn.makePolarMap()
# Out:
# CPU times: user 693 ms, sys: 69.1 ms, total: 762 ms
# Wall time: 7min 50s

# %%
# %%time
horn.makeImpedancePlot()
# Out:
# CPU times: user 516 ms, sys: 137 ms, total: 652 ms
# Wall time: 6min 18s
